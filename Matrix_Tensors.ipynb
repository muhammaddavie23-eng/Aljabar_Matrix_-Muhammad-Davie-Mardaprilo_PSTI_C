# %% [markdown]
# <a href="https://colab.research.google.com/github/muhammaddavie23-eng/Aljabar_Matrix_-Muhammad-Davie-Mardaprilo_PSTI_C/blob/main/Matrix_Tensors.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **NO 1**

# %%
#buat matrix X berukuran 2x3 menggunakan numpy
import numpy as np
x = np.array([[66, 54, 24], [23, 24, 8]])
print(x)

# %%
#tampilkan ukuran dari matrix X
print(f"Ukuran matrix x: {x.shape}")

# %%
#tampilkan seluruh elemen dari kolom pertama dari matrix x
print(x[:, 0])

# %%
#tampilkan seluruh elemen dari baris kedua dari matrix X
print(x[:, 1])

# %% [markdown]
# # **NO 2**

# %%
#ulangi soal nomor 1 menggunakan pytorch
import torch
x_pt = torch.tensor([[66, 28], [53, 98], [32, 74]])
x_pt
x_pt.shape
x_pt[0,:]
x_pt[1,:]

# %%
#ulangi soal nomor 1 menggunakan tensorflow
import tensorflow as tf
x_tf = tf.Variable([[25, 22], [52, 26], [31, 47]])
x_tf
x_tf.shape
x_tf[0,:]
x_tf[1,:]

# %% [markdown]
# <a href="https://colab.research.google.com/github/muhammaddavie23-eng/Aljabar_Matrix_-Muhammad-Davie-Mardaprilo_PSTI_C/blob/main/Exercises_on_Algebra_Data_Structures.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

x = np.array([[25], [2], [-3], [-23]])
print(x)

print()

x_t = x.T
print(f"Hasil Transpose dari x_t adlalah : {x_t}")

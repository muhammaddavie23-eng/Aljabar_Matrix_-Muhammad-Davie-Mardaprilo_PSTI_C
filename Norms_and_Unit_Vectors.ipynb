# %% [markdown]
# <a href="https://colab.research.google.com/github/muhammaddavie23-eng/Aljabar_Matrix_-Muhammad-Davie-Mardaprilo_PSTI_C/blob/main/Norms_and_Unit_Vectors.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **NO 1**

# %%
import numpy as np
#buat vector x dengan ukuran 3x1
x = np.array([1, 3, 7])
print (x)
x.shape
# Out:
# [1 3 7]
# (3,)

# %%
#hitung nilai L2 norm dari vector x
(1**2 + 3**2 + 7**2)**0.5
# Out:
# 7.681145747868608

# %% [markdown]
# # **NO 2**

# %%
#buat vector v dengan elemen (3,4)
v = np.array([[3], [4]])
print(v)
# Out:
# [[3]
#  [4]]

# %%
#hitung nilai L2 norm dari vector v
(3**2 + 4**2)**0.5
# Out:
# 5.0

# %%
#tampilkan unit vector dari vector v
norm_v = np.linalg.norm(v)
print(norm_v)
# Out:
# 5.0

# %%
#hitung panjang unit vector dari vector v
unit_v = v / np.linalg.norm(v)
np.linalg.norm(unit_v)
# Out:
# np.float64(1.0)

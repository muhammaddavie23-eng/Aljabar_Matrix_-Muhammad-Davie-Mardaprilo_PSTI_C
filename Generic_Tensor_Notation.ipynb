# %% [markdown]
# <a href="https://colab.research.google.com/github/muhammaddavie23-eng/Aljabar_Matrix_-Muhammad-Davie-Mardaprilo_PSTI_C/blob/main/Generic_Tensor_Notation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#jelaskan tentang perintah ini
import torch as pt
import tensorflow as tf
images_pt = pt.zeros([32, 28, 28, 3])
images_pt

#penjelasan =
#images_pt = pt.zeros([32, 28, 28, 3])
#32  → Batch size (32 gambar sekaligus)
#28  → Tinggi gambar (28 pixel)
#28  → Lebar gambar (28 pixel)
#3   → Channel warna (RGB)

# %% [markdown]
# <a href="https://colab.research.google.com/github/muhammaddavie23-eng/Aljabar_Matrix_-Muhammad-Davie-Mardaprilo_PSTI_C/blob/main/Skalar.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **NO 1**

# %%
 #buat variabel skalar x dan simpan suatu nilai skalar
#buat variabel skalar y dan simpan suatu nilai skalar
#tampilkan tipe data dari y
#jumlahkan x+y
#buat variabel bernama x_float dan simpan suatu nilai desimal
#jumlahkan x_float dengan y
#tampilkan tipe data dari x_float

 x = 69
 print(type(x))

 y = 77
 print(type(y))

 print (x+y)

 x_float = 9.11

 print (y + x_float)
 print (type(x_float))

 print (x_float + y)
# Out:
# <class 'int'>
# <class 'int'>
# 146
# 86.11
# <class 'float'>
# 86.11

# %% [markdown]
# # **NO 2**

# %%
#lakukan tahapan pada soal 1 dengan menggunakan tensorflow

import tensorflow as tf
X_tf = tf.Variable([[x], [x+y], [x_float+y]])
X_tf
# Out:
# <tf.Variable 'Variable:0' shape=(3, 1) dtype=float32, numpy=
# array([[ 69.  ],
#        [146.  ],
#        [ 86.11]], dtype=float32)>

# %% [markdown]
# ## **NO** **3**

# %%
#lakukan tahapan pada soal 1 dengan menggunakan pytorch

import torch

X_pt = torch.tensor([[x], [x+y], [y+x_float]])
X_pt
# Out:
# tensor([[ 69.0000],
#         [146.0000],
#         [ 86.1100]])

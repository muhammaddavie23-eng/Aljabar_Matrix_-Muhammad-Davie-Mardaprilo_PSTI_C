# %% [markdown]
# <a href="https://colab.research.google.com/github/muhammaddavie23-eng/Aljabar_Matrix_-Muhammad-Davie-Mardaprilo_PSTI_C/blob/main/Vectors_and_Vector_Transposition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **NO 1**

# %%
#buat vector x dengan ukuran 3x1

import numpy as np

x = np.array([99, 60, 51]) # type argument is optional, e.g.: dtype=np.float16
x
# Out:
# array([99, 60, 51])

# %%
#hitung panjang vector x

len(x)
# Out:
# 3

# %%
#tampilkan ukuran vector x

x.shape
# Out:
# (3,)

# %%
#tampilkan tipe data dari vector x
type(x)
# Out:
# numpy.ndarray

# %%
#akses elemen pertama dari vector x
x[0]
# Out:
# np.int64(99)

# %%
#tampilkan tipe data elemen pertama dari vector x
x[0]

# %% [markdown]
# # **NO** **2**

# %%
#lakukan transpose pada vector x dan simpan pada variabel x_t
x_t = x.T
x_t
# Out:
# array([99, 60, 51])

# %%
#tampilkan ukuran dari vector x_t
x_t.shape
# Out:
# (3,)

# %%
#lakukan transpose pada vector y dan simpan pada variabel y_t
y_t = y.T
y_t
# Out:
# array([[67],
#        [69],
#        [66]])

# %%
#tampilkan ukuran dari vector x_y
y_t.shape
# Out:
# (3, 1)

# %% [markdown]
# ## **NO** **3**

# %% [markdown]
# # **Pytorch**

# %%
#lakukan soal nomor 2 menggunakan pytorch dan tensorflow

import torch as pt
x_pt = pt.tensor(x)
x_pt
# Out:
# tensor([99, 60, 51])

# %%
x_pt.shape
# Out:
# torch.Size([3])

# %%
y_pt = pt.tensor(y)
y_pt
# Out:
# tensor([[67, 69, 66]])

# %%
y_pt.shape
# Out:
# torch.Size([1, 3])

# %%
x_pt = x_pt.T
x_pt
# Out:
# tensor([99, 60, 51])

# %%
x_pt.shape
# Out:
# torch.Size([3])

# %% [markdown]
# # **Tensorflow**

# %%
import tensorflow as tf
x_tf = tf.Variable([9, 19, 3], dtype = tf.int32)
print(x_tf)
# Out:
# <tf.Variable 'Variable:0' shape=(3,) dtype=int32, numpy=array([ 9, 19,  3], dtype=int32)>

# %%
x_tf.shape
# Out:
# TensorShape([3])

# %%
y_tf = tf.Variable([88, 76, 12], dtype = tf.int32)
print(y_tf)
# Out:
# <tf.Variable 'Variable:0' shape=(3,) dtype=int32, numpy=array([88, 76, 12], dtype=int32)>

# %%
y_tf.shape
# Out:
# TensorShape([3])

# %%
x_tf = tf.transpose(x_tf)
print(x_tf)
# Out:
# tf.Tensor([ 9 19  3], shape=(3,), dtype=int32)

# %%
x_tf.shape
# Out:
# TensorShape([3])
